# %% [markdown]
# 原文代码作者：François Chollet
#
# github：https://github.com/fchollet/deep-learning-with-python-notebooks
#
# 中文注释制作：黄海广
#
# github：https://github.com/fengdu78
#
# 代码全部测试通过。
#
# 配置环境：keras 2.2.1（原文是2.0.8，运行结果一致），tensorflow 1.8，python 3.6，
#
# 主机：显卡：一块1080ti；内存：32g（注：绝大部分代码不需要GPU）
# ![公众号](data/gongzhong.jpg)

# %%
import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# '2.2.1'

# %% [markdown]
# # Text generation with LSTM
# #  使用 LSTM 生成文本
#
# This notebook contains the code samples found in Chapter 8, Section 1 of [Deep Learning with Python](https://www.manning.com/books/deep-learning-with-python?a_aid=keras&a_bid=76564dff). Note that the original text features far more content, in particular further explanations and figures: in this notebook, you will only find source code and related comments.
#
# ----
#
# [...]
#
# ## Implementing character-level LSTM text generation
#
#
# Let's put these ideas in practice in a Keras implementation. The first thing we need is a lot of text data that we can use to learn a
# language model. You could use any sufficiently large text file or set of text files -- Wikipedia, the Lord of the Rings, etc. In this
# example we will use some of the writings of Nietzsche, the late-19th century German philosopher (translated to English). The language model
# we will learn will thus be specifically a model of Nietzsche's writing style and topics of choice, rather than a more generic model of the
# English language.
#
# ## 实现字符级的 LSTM 文本生成
#
# 下面用 Keras 来实现这些想法。首先需要可用于学习语言模型的大量文本数据。我们可以使用任意足够大的一个或多个文本文件——维基百科、《指环王》等。本例将使用尼采的一些作品，他是 19 世纪末期的德国哲学家，这些作品已经被翻译成英文。因此，我们要学习的语言模型将是针对于尼采的写作风格和主题的模型，而不是关于英语的通用模型。

# %% [markdown]
# ## Preparing the data
#
# Let's start by downloading the corpus and converting it to lowercase:
#
# ## 准备数据
# 首先下载语料，并将其转换为小写。

# %%
import keras
import numpy as np
path = 'data/nietzsche.txt'
#这个数据已经下载好了，在上面那个路径
# path = keras.utils.get_file(
#     'nietzsche.txt',
#     origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Corpus length: 600893

# %% [markdown]
# Next, we will extract partially-overlapping sequences of length `maxlen`, one-hot encode them and pack them in a 3D Numpy array `x` of
# shape `(sequences, maxlen, unique_characters)`. Simultaneously, we prepare a array `y` containing the corresponding targets: the one-hot
# encoded characters that come right after each extracted sequence.
#
# 接下来，我们要提取长度为 maxlen 的序列（这些序列之间存在部分重叠），对它们进行 one-hot 编码，然后将其打包成形状为 (sequences, maxlen,unique_characters) 的三维 Numpy 数组。与此同时，我们还需要准备一个数组 y，其中包含对应的目标，即在每一个所提取的序列之后出现的字符（已进行 one-hot 编码）。

# %%
# Length of extracted character sequences
# 提取 60 个字符组成的序列
maxlen = 60

# We sample a new sequence every `step` characters
# 每 3 个字符采样一个新序列 
step = 3

# This holds our extracted sequences（保存所提取的序列）
sentences = []

# This holds the targets (the follow-up characters)
# 保存目标（即下一个字符）
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus（语料中唯一字符组成的列表）
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
# 一个字典，将唯一字符映射为它在列表 chars 中的索引
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
# 将字符 one-hot 编码为 二进制数组
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 58
# Vectorization...

# %% [markdown]
# ## Building the network
#
# Our network is a single `LSTM` layer followed by a `Dense` classifier and softmax over all possible characters. But let us note that
# recurrent neural networks are not the only way to do sequence data generation; 1D convnets also have proven extremely successful at it in
# recent times.
#
# ## 构建网络
# 这个网络是一个单层 LSTM，然后是一个 Dense 分类器和对所有可能字符的 softmax。但要注意，循环神经网络并不是序列数据生成的唯一方法，最近已经证明一维卷积神经网络也可以成功用于序列数据生成。

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %% [markdown]
# Since our targets are one-hot encoded, we will use `categorical_crossentropy` as the loss to train the model:
#
# 目标是经过 one-hot 编码的，所以训练模型需要使用 categorical_crossentropy 作为损失。

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## Training the language model and sampling from it
#
#
# Given a trained model and a seed text snippet, we generate new text by repeatedly:
#
# * 1) Drawing from the model a probability distribution over the next character given the text available so far
# * 2) Reweighting the distribution to a certain "temperature"
# * 3) Sampling the next character at random according to the reweighted distribution
# * 4) Adding the new character at the end of the available text
#
# This is the code we use to reweight the original probability distribution coming out of the model,
# and draw a character index from it (the "sampling function"):
#
# ## 训练语言模型并从中采样
# 给定一个训练好的模型和一个种子文本片段，我们可以通过重复以下操作来生成新的文本。
# * (1) 给定目前已生成的文本，从模型中得到下一个字符的概率分布。
# * (2) 根据某个温度对分布进行重新加权。
# * (3) 根据重新加权后的分布对下一个字符进行随机采样。
# * (4) 将新字符添加到文本末尾。
#
# 下列代码将对模型得到的原始概率分布进行重新加权，并从中抽取一个字符索引［采样函数（sampling function）］。

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# Finally, this is the loop where we repeatedly train and generated text. We start generating text using a range of different temperatures
# after every epoch. This allows us to see how the generated text evolves as the model starts converging, as well as the impact of
# temperature in the sampling strategy.
#
# 最后，下面这个循环将反复训练并生成文本。在每轮过后都使用一系列不同的温度值来生成文本。这样我们可以看到，随着模型收敛，生成的文本如何变化，以及温度对采样策略的影响。

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# Epoch 1/1
# 200278/200278 [==============================] - 215s 1ms/step - loss: 1.9824
# --- Generating with seed: "alumniators and detractors, even when they still remain our
# "
# ------ temperature: 0.2
# alumniators and detractors, even when they still remain our
# wand and scient and something the great and the concertions of the preasons of the belise such a the sumpless of the presense of the presense of the believes and a conders and such a menound and the sumplences of the fast the preason of the mental something the self the presens of the preason of the presense of the fact and the means of the measer of the wally and such a the sumpless of the contri
# ------ temperature: 0.5
# he measer of the wally and such a the sumpless of the contrine in the sumpless and the noce and sefal and mentines, and that the freed sumblent the meads the in the such a distiments of must in the spirit and smouls thenelves individual of
# the despersion of the for the purcomity, and simply be invereness of the fend the faules of the preasous of all a would the great to which
# in the scoull in a love to the the well is
# the become in the fart man a dirple an
# ------ temperature: 1.0
# ve to the the well is
# the become in the fart man a dirple and
# misteds all then introods regrore his
# agradom of a mause they nawnar "among-nameons and then now
# deligiinato the fancage a green prestem, and thought: them,
# wand hfon nabces it placasion and are reids hor befolse privirss of metervisifeence emplious no say" pase
# suchition, and stroader difsationsgatismance in the if the the misul--the heirs; as this a
#
# now will," theyselfry shemtenced--no door i
# ------ temperature: 1.2
# eirs; as this a
#
# now will," theyselfry shemtenced--no door injo-tnately, fearori, ons
# suevel
# should valicie to et life corlice
# affererads exemes pitice opriclly divleces than
# thrwerveh barefwertious piolous to somer in feelny,
# aptrity man-to8ece sicticity
# humaby puseness, this
# "nowh to highy hem it is
# in
# doondublems,  ""wholorge unjuat
# by hooac
# essernire is knifere, wholso bohice .owise, of privilote out it is sumborred fool? thut a fins the rele-edented a
# epoch 2
# Epoch 1/1
# 200278/200278 [==============================] - 212s 1ms/step - loss: 1.6290
# --- Generating with seed: "ough they may dash and break their heads thereon. people hav"
# ------ temperature: 0.2
# ough they may dash and break their heads thereon. people have the profor the stranger the fact of the proment and spirit and state of the promment and the art of the same and more and state of the same the profound the farther of the concessition of the promation of the same the mankind and not the profor of the concessition of the condition of the fast and state of the mankind and mankind the distiment of the fastion of the concemstance of the proment and
# ------ temperature: 0.5
# timent of the fastion of the concemstance of the proment and the comparation of comparis in our terse of a way and strangure and in the disinternation of the new asward and moral which not been the concessition of the fore their free species is course and other which the make the former and men and mort light to a prescent and higher from the canter of some and philosophers and still in the spirital because the mast the greek of the nor in the some and "ma
# ------ temperature: 1.0
# al because the mast the greek of the nor in the some and "matich contitions,
# in fromoruring of the methinc and innect and fore relight
# radiful moved alweltaw its race!
#
# nawieves sernating, is unmich indeed ans should of for as the namily for comparoce, rake.
# this a soler--as
# the fact mattrably doubly inaty of should bested--and apaus! in
# the certaind that a lrom spoclued, estemational--and wret regover the arem findly
# mated
# intersany, mental dagent.uph hi
# ------ temperature: 1.2
# egover the arem findly
# mated
# intersany, mental dagent.uph his asconte of ricine, intelved intemplatace in inlenemed would
# nothy
# to !   fastificatiod beparawewads.y--of every diver  tive him accornce.
# poger homed. in whented world intempt
# ow obldamty, from what curtimsely a
# knowpelt shopted combleration of them ap unjichticatic thes, and centirence rodings atcelt patain" pretoole; we can, will with me stees without
# bith, w.
# -long herchrie theirs
# epis anteke
# epoch 3
# Epoch 1/1
# 200278/200278 [==============================] - 210s 1ms/step - loss: 1.5387
# --- Generating with seed: "rse in general. the
# whole teleology is so planned that man d"
# ------ temperature: 0.2
# rse in general. the
# whole teleology is so planned that man deception of the sense of the same there is a soul-possible and so the philosophy of the same the sense and persorated the concerning and so the soul-possible and personal simples of the most such a manifest and all the same the sense of the same the same them as a manifests and self-should the have no longer the same themselves and as a so the present the existences of the sense of the same the co
# ------ temperature: 0.5
# o the present the existences of the sense of the same the comparish and manifest
# and therefore: it if the same that it is a feels of the mode of the desire and of the same and dependence of their therefore, not in the motive and of the good an organity the contentions, and it is all the atters of a reserve as a "most careness--and that a have boons, the more therefore: it is an and the fack and as lain that the same come as the disconduct the corness and s
# ------ temperature: 1.0
#  lain that the same come as the disconduct the corness and sided truth are manifind fat of the
# keatherress appegience, as for sromet which its world. withnee, i has but over one even any pomsied adattery, as a philosopher of instincts and ethics, and refinen for the best it
# is whatever: oribliables not to
# sevied which with world and
# know--que manifiply all in
# the "mirdamatic of about according, sansdon, the knowledweed in a macher tye puted to virturis of
# ------ temperature: 1.2
# nsdon, the knowledweed in a macher tye puted to virturis of the greetol-phang, if should i darmination. as could or acvores they not an excectesting! "whereo), teal. time open is aldoven are bemoor". -etfully no  ochaponsuphy enlog whoever
# veupond, a mabore once anx
# mastestely its sayem to dispetted wither a prived unto account  bry plamrest having-prehent can ficition, otherly aqker symp time has navesi: would otigatation."--is
# estaffustreby if matherisie
# epoch 4
# Epoch 1/1
# 200278/200278 [==============================] - 916s 5ms/step - loss: 1.4939
# --- Generating with seed: "s
# the truth. hence the child has faith in the judgments of i"
# ------ temperature: 0.2
# s
# the truth. hence the child has faith in the judgments of intellection of the spirit of the spirit and fact and the more soul and action and the spirit of the man in the same for the same the constrained the superie of the man and soul and and the more so the most the soul and the same and in the instincts of the mankind and the man and soul and the more so the strength and the same the more subject the most desire and the strength and the fact of the sam
# ------ temperature: 0.5
# ect the most desire and the strength and the fact of the same and or and the manner the deception and begerd deferent, in the consequents of religion of the man and sthen of reality, the instincts the can some desire the way his decreation of the man and precisely and precisel and the more suffering the sense of satisfactic from the refore interporances the does the most mankind and differentable and "intellectiality in any of constitute and the hand ether
# ------ temperature: 1.0
# and "intellectiality in any of constitute and the hand ethertoful, to be be be-ill general political mankind and vain with refine-manding good be still a dictionment of mankind said betray
# a, indeed estationty and so
#  and commisicy great overeable of idmany! preciment of commut iast and impthaper not interpedority's bindst and pley
# aphriciouing and
# nather man, if they deeped ophires,
# and
# nightnessain honesty in
# religiod dign subject"
# indiffereat any once
# c
# ------ temperature: 1.2
# ain honesty in
# religiod dign subject"
# indiffereat any once
# cally dret, ay of ciection, such to a "cerience and
# precysely modeer," tod, and liade lone. no bove which has "caples the driugid forching mound sgimes deris. his good have in sa.'s, ratuis were. feeld accome
# powh,
# eper itiving reid so--inteful as erroruring about the the hack with
# that dagfelm heigved psonzes h, to devil arm for own pleasure, is fettering work
# recillness. knowledgenting more self-
# epoch 5
# Epoch 1/1
# 200278/200278 [==============================] - 915s 5ms/step - loss: 1.4647
# --- Generating with seed: "on of
# woman in the hitherto existing order of society has en"
# ------ temperature: 0.2
# on of
# woman in the hitherto existing order of society has entire and the sensition of the sense of the most the most the sense of the same and in the power and something and something and the all the more something and something and a more and in the belief to the sensition of the sensition of the soul and a mankind and something and the such a man conscience of the same the man who has a man and society of the more something in a more such a power and a m
# ------ temperature: 0.5
# society of the more something in a more such a power and a man to a man who former and he does he discomplemation is a must we cominary from the man formed those something is whole is not as one must be destrayment to mankind and the must against and too are a constardite and opposition of himself is not a society. he was a pain himself of the super-tastition of the purat to the dominate is one may be a more mankind once may be world a time and soul and so
# ------ temperature: 1.0
# y be a more mankind once may be world a time and soul and so to stood does sought conceptageding are, suffering who me
# metormy and
# bands, as while sick. they have it sansitumament and ablutics
# self-one" will be thes
# taste. was as thrikes, once he and sother to
# sway and while destrugainy of moral oppurely castes and suffry memothsing is netide he attention-own should queived
# mornes, the stable their
# all he oddracul cultures the reston, her, who is, artilig
# ------ temperature: 1.2
# ir
# all he oddracul cultures the reston, her, who is, artilig enough prstorable in the portrycapatt
#   unshow -where, supis would cainfting to have books; irself,
# hus, depact, ethiis from which
# he has this bit have been thoral
# knowlesily woughty doftness, on the odined they zaves, of his dese
# as : that he call "time a
# didt (of truth. they shiughty, among for a even theself knowledgek setplasy as the german super-to one whole
# "echoparism
# greas course
# to the a
# epoch 6
# Epoch 1/1
# 200278/200278 [==============================] - 913s 5ms/step - loss: 1.4440
# --- Generating with seed: " though they would choke and
# strangle it, out of jealousy--a"
# ------ temperature: 0.2
#  though they would choke and
# strangle it, out of jealousy--as the same the master of the same the senses of the such a same and also the senses of the same the properating of the mastering with the strength and the properting of the mastering to the such a spirit and self-such a specialing of the same self-contempt to the exception of the same the present perhaps in the same the present problems of the same the strength and any strong in the problems of th
# ------ temperature: 0.5
# f the same the strength and any strong in the problems of the master. they mast bely as we listtent of the ears of the senses, the man the case of all the are, as in the properting of one has it "doing to the free oneside of the world is also the way, the may be of the acts of thoughts of present its fears and same to the may being of the present from which a man belief the properating not only be stringing to the also such case of the contempt, which is a
# ------ temperature: 1.0
#  stringing to the also such case of the contempt, which is a desided wwith the stept us, may, knowledgeing bedwered, too, but perpections of the class to vat ood there is not former for the poses, the dacture epotesing whether entire insteltion, the desirated, and without man out of uses. the high a pact to been his deceive is or "re to,ar to its modeped of gheeit opining, has
# cury least marky ones distrmining, perhaps. assoul pictisying wommsteruss, desir
# ------ temperature: 1.2
# s distrmining, perhaps. assoul pictisying wommsteruss, desire, ach of emplair.--unjust, are from is as malical ifere, accipe he laugh ensted outsis may,
# other wold giftics, belwe crasing himself perhap outsibed subst: they greeky renvespived who mad, he frond, through caplationsly, pyolably presentrals, its haged to be or lat
# eyules: "dears animal mischie any instinct had rearar, civilization
# of
# every tad persiny,--every long tell" tooy
# most goods of the s
# epoch 7
# Epoch 1/1
# 200278/200278 [==============================] - 915s 5ms/step - loss: 1.4262
# --- Generating with seed: "result of two
# prior, single, separate feelings, is judgment "
# ------ temperature: 0.2
# result of two
# prior, single, separate feelings, is judgment and self-who has a man with the man and the same and the sense of the worth and the most the man that it is a man with the most and the man that the consequencealing the sense of the most present the man the most and the same the man with the sense of the most and with the world to a man is a man is a man is a man is a man is a man with the master and the sense of the worth the world to the conseq
# ------ temperature: 0.5
# he master and the sense of the worth the world to the consequencealing and interposing to a problem of the most case to the developation of the consequently the so the all the consequently the problem with a man of the mast of every one must be see the world to consequently the origin of the worth as it is to a world to him, to the bad and most unwerced to a person of the standard in the instinct and pain, and therefore the master of the manifest, and the
# ------ temperature: 1.0
# and pain, and therefore the master of the manifest, and the profes frontions hard on anoty todgrtation in the religious ourself--and are communitiments and necessant advace that the reard? and i belold at any tranition too kand! wile" of the remain form for loal-extralant
# and each hunger, perhapphy,
#  and existence is not be sages although the can be his inventions have sturition of the fullert ending, and to prived ie a, it is lat prenciptable as of these
# ------ temperature: 1.2
# ding, and to prived ie a, it is lat prenciptable as of these the
# on the falseaie convcived. takvous spholh, modalqued, raceds woman because
# here w it "ih? even.
#
# 21.
#
# 1 if well impure, ratudonce,"--there are generally unteltiaquarence, to a fective, wit, vensure to grow
# his siny, ivens should "nature, o cosmoit exploftice).
#
# 1
# newer home and at long-equcings, and that sy to "what myself: we that this coaster, or ifulssedel their doging tarughtnouranis of a
# epoch 8
# Epoch 1/1
# 200278/200278 [==============================] - 912s 5ms/step - loss: 1.4122
# --- Generating with seed: "e
# case of every other people, is unfortunately only too ofte"
# ------ temperature: 0.2
# e
# case of every other people, is unfortunately only too often the spirit and the sense of the most in the contradistic of the spiritual so the spiritual and of the spirit and the spirits of the same of the spirits of the spiritually and conception of the sense of the supposing of the strength the strength and the supposing in the most and the spirit of the the spiritual and of the spirit and properting of the strength the most the soul of the man and the c
# ------ temperature: 0.5
# rting of the strength the most the soul of the man and the conception of the meaning something that and in the deluch the most the feeling from the real and something for the sense of the supposing the present be rule the sentiment of the dile soul in all the the made and messical superioric of their sense of the spirits of all the most realing, and enthusial man is a supposing, in shain to the eaged in the same the proor and propertion, as the probed in t
# ------ temperature: 1.0
# ged in the same the proor and propertion, as the probed in the science, what wait because is fortrnance. there
# who noglopely but they would beneld very being,
# costopanme all object
# "herothing to misuaged end "duilo of the gercain under wagne devblencacily for envieor,
# when if one of ahreaing as his pertantly, is no lest as our may be wait, has have proves its
# to victises,
# when is a
# still
# habit, are!
#
#
# 1itur of him had have long sucerbarish of bold percepti
# ------ temperature: 1.2
# e!
#
#
# 1itur of him had have long sucerbarish of bold perceptioned
# european, a there; as the fortocati in grothess--whe can preces,
# suffercs strothes groufl and as lude who once
# soay now-
# unrall"" "viduce judged short, no plive--the judice in nor involume a dowethiz and the reactifit only all, the
# decitedhy on durity--his
# trosth-yhor. but we religive seent
# of an
# paromat -himself not a probes ask of whoo
# new vaditiin of the
# same! simply the sgly" heypists' "a
# epoch 9
# Epoch 1/1
# 200278/200278 [==============================] - 914s 5ms/step - loss: 1.4009
# --- Generating with seed: "sire for "freedom of will"
# in the superlative, metaphysical "
# ------ temperature: 0.2
# sire for "freedom of will"
# in the superlative, metaphysical and the more that the contempt of the more and the strength and in the strength and the most still the more all the spirits that the most soul in the form of the more strength and the more sublime to the more and whole form of the part of the strength and the subjection of the promise the same than to the more spirits and soul and the more and the same in the spirits and the strength and the more
# ------ temperature: 0.5
# e and the same in the spirits and the strength and the more than the powerful the philosopher cases the moral to the man and acquives of the conscious of the reals of the all the present does not be different and souls of the way itself--for the most man the ears of comparation of the europe of the constitute of the world to self--and the basis of the extent in the strength in the more struggle that the right that the personal the tested in the master of t
# ------ temperature: 1.0
# at the right that the personal the tested in the master of the geverties of bark, but finger whiche surone mbat its rulal spirits of macking begins is lits irs the sin, camiling to pace sensusts and tywards he
# arte offed strenglon and deplike than to the beaves good man homatic-placed of saveloners is metaphysical
# crieng manifests
# peised pain once the sucridiscies both which is do nowanase, the general nebilate on which is tod time as
# devalit.
#
# na
# presoung
# ------ temperature: 1.2
# neral nebilate on which is tod time as
# devalit.
#
# na
# presoungs, who abpulse as "becashem lames o philosophers of this evil, us "your to cannast fath a dovatesx--on embliging in schollyy that religion most accommand against a human ;" i becoming unldomexull lippens from all to othep; bus no
# blencessive). indeed, this really fals means, with force." severic more discanted in and unaccormenokee times, nor
# enthrle, it not wordwing his torth it crio: tmusics, to
# epoch 10
# Epoch 1/1
# 200278/200278 [==============================] - 916s 5ms/step - loss: 1.3913
# --- Generating with seed: "y itself, however, has
# been regarded as something "given." h"
# ------ temperature: 0.2
# y itself, however, has
# been regarded as something "given." he will strength and more something in the superiority of the sense of the strength and spirit and spirit and the strength and soul seems to the strength and sense of the most consideration of the sense of the sense of the strength the strength and strong and strong and such a soul and sense of the promise and more and spirit and the spirit of the conduct the sure of the strength and something with
# ------ temperature: 0.5
# t of the conduct the sure of the strength and something with the more such as a general
# significance of which the strew has a threat on which a stronger of the good to understand of the such sense of the interpret to present difficult of the same who state of the soul and should the same might the fact the word of his passionally possible that his complete the most be something which the science as the complexirate it is the word whatever he expediency of
# ------ temperature: 1.0
# s the complexirate it is the word whatever he expediency of every smod"" learned are something sundeed; of nature of us"ificable frost to itselft e! the
# deed by necessity; this should
# how other, one is after,
# reilogy at likered
# party is here not englishd" and like-accurable
# condition-vylon
# one morely grown reprepord too like young and "nature is, the fear, even and
# science, even
# at least deminse things of compares, as as all
# does something of intelligemati
# ------ temperature: 1.2
# hings of compares, as as all
# does something of intelligematic frishep to cha is own war knot which whate? his dorally, for who
# right
# with a pruites. altht the might beberiing underlance--seldom his more acceptine, afsort and
# evil is and misus is but let beoveerfuls at englith uimaging from matter
# may also ma: the experiences,
# formerly quiscionalitn, and really
# laity, silence (and come--him. for hhis a imparenced anct"--and the fear tetenne would vere in l
# epoch 11
# Epoch 1/1
# 200278/200278 [==============================] - 918s 5ms/step - loss: 1.3822
# --- Generating with seed: "s in
# common. on this account the people of one nation unders"
# ------ temperature: 0.2
# s in
# common. on this account the people of one nation understanding and subtle and soul and the strength in the same than the strength and the subtle the stranger and soul and the philosopher in the strength it is always and the great the same than to a consists and the consists to a philosopher and believe and the more strange the sense of the strength and from the sense of the same the subtle the sense that the same of the same than the strength and self
# ------ temperature: 0.5
# e sense that the same of the same than the strength and self-disparation of a more and the self-knowledge of the resture of philosophers and subtling the strong subtle art him to possibing the science of the radical pain of the intention of the lits to be more intellect
# and morality and
# that it not preduce in the supersicial who was also for the most immense is considorism of the struggle and good of standant, and a free spirits and nothing of it, to be be
# ------ temperature: 1.0
#  of standant, and a free spirits and nothing of it, to be be philosical called, woman in.--at fore--lest. it  loal.
#
# 21nes have to merore, must from the rentials of every circlation with religions it: woman inceal and
# adventure pasvious agesually grows, i part of ennow, skeps that is now a lat the more, the corrowary which me
# case that old antime, presence that is also the to man
# dangers, are a abyst
# counting free life, "impativedising to an
# diversious in
# ------ temperature: 1.2
# yst
# counting free life, "impativedising to an
# diversious in viciousior
# armotife. is means life--it is the according that shome. afffirence is absolect before what "a clount, and if i mean them moral ammud, superimman, artofr, it has not to expedience" andaquery, bstich apdaded; and thin guroriina of brings thry cat mis: "let too ?the =vermaled, bear has it it not not to palsum
# obtainty; we has more englishmance and
# powerff
# feal
# same sick. both ie treat all
# epoch 12
# Epoch 1/1
# 200278/200278 [==============================] - 915s 5ms/step - loss: 1.3756
# --- Generating with seed: "ealed under the most venerated types of contemporary moralit"
# ------ temperature: 0.2
# ealed under the most venerated types of contemporary morality of the subjucted the most superficial to the man and self-desire to the strong and considerations of the same and soul and the most perhaps the cause and soul, and the strong and sense of the contrary the contrary to the most the contrary the world and self-always be a thing the strong to the problem to the same and the contrary to the same of the most the contrary the contrary the particular an
# ------ temperature: 0.5
# same of the most the contrary the contrary the particular and acts and boundr's--and there is the basis of the books as the position of the proved and man with the contrary the highest a tained to a new paration, the way as solitude, and a complexation of the most feeling of honour, the great previous and partions itself of the saint and self-desire to the rearn the world of interesting of the soul, as the ancient who
# was one soul and the spirit of the str
# ------ temperature: 1.0
# l, as the ancient who
# was one soul and the spirit of the stronged and sike grown old civilonce and cal in rebire under the cause to reas hofteat, howevers to be fiftire exitual one latt. shart of fact "good long our learnest, a full," is not centurely
# if self one
# in this wast protod eom
# is name anoungeate and venlection." and like it boul real
# love with one sounds.
#
#
# 1set.
#
# 1
# the
# greing. the
# sense: if the "paroicals a frence of
# circlationm the "grod estim
# ------ temperature: 1.2
# e: if the "paroicals a frence of
# circlationm the "grod estimate, we arxite
# lessumes to o pand one cassuonal la; fine;timent. at have wenders, to a good as
# name of one then not something folly), i must rather not soul that instinctskely enoughs
# in personawly
# descens oneself. capnica play, and religing. dispicely with all
# a; you
# deed is confline.
# inderen the
# evolve wor, interous, ago popitions. the hone, a gratill."
#
# rentmomon suffers. there are intellingn,
# epoch 13
# Epoch 1/1
# 200278/200278 [==============================] - 915s 5ms/step - loss: 1.3686
# --- Generating with seed: "nce of the deportment of love that
# is promised in every inst"
# ------ temperature: 0.2
# nce of the deportment of love that
# is promised in every instinct of the man and the man and the man and conscience of the form of the same the man and the most spirit and sense and soul and the conscience of the world the start the way of a more man and the start the same and the way of the contempt the man and the sense and the same and some the man and the interestion of the transmance of the most and the man and sense of the same and mankind of the man
# ------ temperature: 0.5
# st and the man and sense of the same and mankind of the man be all the man all the proved, and condition of the immediately to a man, the way to charmation and society that the conterminally for the man of an action of the way and
# the man which has been pleasure to a many promoin of the english artic love and of the master of the freedom. the same truth, and self-sacrifice in the fears and purlos to be feeling in the end of the sensition to good in new con
# ------ temperature: 1.0
# to be feeling in the end of the sensition to good in new consiuth thrind by ovircuternate
# inorigin" in the magine quiroly gard, what is only, what is always saarting as
# and should too hearing worn perhaps, by the teculim, lightents, (or in wimang caset, to the same become
# art forth, these pertains and for simpler as painture is deervened to asbah as
# self memorous believed" view,
# glade art look in the , wh
# c:\programdata\anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# oever scient, but but messe are
# another was with ag
# ------ temperature: 1.2
#  the , whoever scient, but but messe are
# another was with agrieot egn wfore, aganticas fethef: right, who trained upon in coar, to him (why before an
# adgming samed as
# dote"; whom every free, woman
# in the inxrition of cloif merely, owing narronungred could "go best and thwatest strict, at usence, can name, faurling
# greats of its
# awtrouse, to wrous what
# we y beoulisnorsness, life now to the moder dabve. however pinual thing in
# sucerle.--mankind line
# europe w
# epoch 14
# Epoch 1/1
# 200278/200278 [==============================] - 913s 5ms/step - loss: 1.3628
# --- Generating with seed: "ible, therefore, to
# impose some guidance upon the forces of "
# ------ temperature: 0.2
# ible, therefore, to
# impose some guidance upon the forces of the same to the states of the reason to the sentiments and soul in the world to the subject of the sense of the same to the strength of the subject of the strength of the stipidation of the subject and soul and the things and self-deceation of the spirit and subject of the strength of the sense is not a soul and self-delight and soul and soul and subject of the world and destruction of the subject
# ------ temperature: 0.5
# soul and subject of the world and destruction of the subject in delight, and in the sways in the end, and man something of life--the superficiants of a forming of the assume in the destrust of the sense and the love of a world and woman of the should as it is the same of the fact subject, something in the same own one in a fact to the superficial to such a subject and dangerous would does
# not instincts and subject in the things the hounds. the same of comp
# ------ temperature: 1.0
# incts and subject in the things the hounds. the same of comprised.
#
# 1otly the relumant, babe, the distruct to free
# relakn, as strive which as old not some intellwands to childly in rigkintys had likes he consciously in flappence of the antachich, antaques.sfl
# off toqueswand aspiention amentical little as
# never ideas arempes this
# fixugoness period of
# imposs of acts to faci overctupletation in dimout him essentupintm and prefering, as they werced, were not t
# ------ temperature: 1.2
# t him essentupintm and prefering, as they werced, were not this may ?twif; comlongly its own
# solety,awn, somet; that whichsous pars,
# read, purens else in the new-ancescion" by
# the deate.
#
# 1itin
# tlonding-in this fea oldgationing and
# does
# not do shid, however for
# welk his prowewn a salvatance and
# desfeance in the blatto-greatershnoful with him, that we beaut placy your spirit and fearce for wrothenes
# even thing morals involuch and dicting, on thosely
# inclanc
# epoch 15
# Epoch 1/1
# 200278/200278 [==============================] - 911s 5ms/step - loss: 1.3575
# --- Generating with seed: " which
# renders obedience, or which he believes renders obedi"
# ------ temperature: 0.2
#  which
# renders obedience, or which he believes renders obedience of the such a state of the same one with the more the same that the fact the fact and the spirit of the suffering of the sense of the strength the state of the same and the spirit of the higher in the man and the belief in the same the personal senses the same and the conceited the species to the present the fact the strength and personal enough to deceive the strength and the more the more a
# ------ temperature: 0.5
# sonal enough to deceive the strength and the more the more and period to experience and distinctive in a light to the bad the treat of the case to the same to be a profound the more there is a more who courses of the mistaken the science them one another in the personal be fausing the more an embrifieness, become in the spirit to rare with interesting things the result of their more higher experience men a things and men that the artists in the state of th
# ------ temperature: 1.0
# nce men a things and men that the artists in the state of these sension to underliess he in first wishing fully to--the higher afford for its immenhencning arifes, reason--the worthy and fore eption to ethike to times, how, to the
# soul a lowed his men has soull os ornerstop to be atame, to havebrous more withest pitive at contrary beorentines for hung about it is science
# "according any actuaur: on that from books themoled" by the christian soar, becomours
# ------ temperature: 1.2
#  that from books themoled" by the christian soar, becomours them" injeal not to inherpates, dotium to cunuces obliged one generally influence. he humblowing, attracless" old great woman! vicably meanm?x and most eye criation was once
# feel concuratring to
# unnovemy for those would ceautionful old wway
# man, or "his fap this w quitives to the philosophy zequio found find not , inceast opposince, him of what was a destructory of o heavy vercaption, solr,      m
# epoch 16
# Epoch 1/1
# 200278/200278 [==============================] - 912s 5ms/step - loss: 1.3535
# --- Generating with seed: "o their
# motive, but solely because of the utilitarian or pre"
# ------ temperature: 0.2
# o their
# motive, but solely because of the utilitarian or present and the same to be all the same to the state of the state of the man and something in the same to the present and soul and the same to be believes the most concealed in the strong of the same to be distinguis of the same to believes the same to the strong and soul and the conceive that is to be believes the states of the strong and the present of a precisely the whole something strong and the
# ------ temperature: 0.5
# he present of a precisely the whole something strong and there man as "where is to an also man to be
# to be himself for examplesion and powerful spirit of the prediced place of the nature of its advances
# in the superioristic and all the deate of the
# free species of the supiting" in the present the most exearting the will that there is also worker in the independentness, he german feelings--he is interribite the superstions for all the word of the present ma
# ------ temperature: 1.0
# terribite the superstions for all the word of the present master," one adouts, he
# would not that a dut, to a to lartyousnonfly amid to the
# pessumeon like presentance to bad defendation in labor," how
# for! e"ble odier , there are once against hime myst froctoking. but when su: which is atroon in the, were arrived
# inductions, really gratitude-great att new inter: to the samilie, knowledge icnom sonatia flate what through fact to liwevome arise as his socres
# ------ temperature: 1.2
# tia flate what through fact to liwevome arise as his socres must it
# decedes--and only mirst conception, thbue
# bumbeneals. which in this, kreletomerry aivy, a nature (thus! how by pacis wh he eme orfuls rend, art can hreathringrly: thoustanms; no longer "tarres, who is name forceed-coursious cule
# orber--and prcienced pompt for
# durefacioncal--if
# netrary withoutleh? like hist
# to
# be
# set that
# has begulo whearisty of morality,
# would perhaps "parte in prope justi
# epoch 17
# Epoch 1/1
# 200278/200278 [==============================] - 911s 5ms/step - loss: 1.3495
# --- Generating with seed: "w was bent!
#      strongest was he by whom such bolt were sen"
# ------ temperature: 0.2
# w was bent!
#      strongest was he by whom such bolt were sense of the subtle the spirit and a problem of the self-desire the man is always and also have the same and the are also some and the same the sense of the present the same and in the same the self-thing of the same and problem of the such a problem of the same are also the same and the same and socies of the most souls of the same and soul is the sense of the same to the same and in the same and pr
# ------ temperature: 0.5
#  is the sense of the same to the same and in the same and precisely in the same self-such the fore the absolute conscience is not been the master speaking self-"man; a our intellectual seems and "the self-place and the states of a more insistence, and the once "bad another as he were moral and dotped themselves and the personal free spirit and be a man exceptional all the other from a god must as "for the significance the spirit and the sin problem on the
# ------ temperature: 1.0
# "for the significance the spirit and the sin problem on the facule free
# spirit" be cray.
#
#
# 1ne is applayences of a functior and
# advanisms.
#
# 18
#
# . one who lifely opinion that an extend and fonement in which the conditions? or advalf all how stonve one should in wherm more a genehr time, such
# a friendsed still agreeable express of
# nine one, however,
# his things," in a form of history to
# a part that most frreno soft bloss to
# an own free sbander tosding this wo
# ------ temperature: 1.2
# ost frreno soft bloss to
# an own free sbander tosding this wonds has pregaunt madual science a god, embend-prod and favour.
#
# 1entl founing worth" with averte opensing this "their views as all that
# psycholofar to impulse his people, and platoge:
# pardive tedly in anwaial stupid, intolitopharium which sun rulrial dut
# hatilogiening
# eftec?
# can be
# trougher ascenciial odiative through nimus for world his
# soldougren, god.b(but an altemity and "sere has been
# brought
# epoch 18
# Epoch 1/1
# 200278/200278 [==============================] - 912s 5ms/step - loss: 1.3454
# --- Generating with seed: "y hurly-burly, as a fixed standard of things. yet
# everything"
# ------ temperature: 0.2
# y hurly-burly, as a fixed standard of things. yet
# everything in the sense of the present the sense of the sense of the delight and present, and it is a man and self-knowledge, and is all the contrary and which is not to the subtle the subtle the same to the spirit and something the superior to the same the present the present spirit and something the sense of the same the state of the conscience of the present the suffering to the same the most spirit and
# ------ temperature: 0.5
# f the present the suffering to the same the most spirit and the more for the involuntary and the contrary and in the concealment of the subtle, and i to an instincts of the belief in the most belief in the most conceptions. the reason to the tempo and sources to the possess of all all the more conception of morals" and and in the reason to his extent to an and and he does not be standard and be understand the standard. the same to its are another of an obj
# ------ temperature: 1.0
# derstand the standard. the same to its are another of an objectame,
# as one does a will, if, and as oftent of emotrines and uprouien which the ras their solitupision to copress the dispained add sourve: "little of all religious
# his own so much be most would not )quess in
# concealmenting gives every is undifition to the called (or that the stes owend these sin
# nobadity of these mucle's,
# suitical heifect. once his soon all the
# gaver opinion, as the pleas one d
# ------ temperature: 1.2
# ect. once his soon all the
# gaver opinion, as the pleas one duned, perhaps to attain himself thee drew, to, of yinguain nationudonred assuhdes to his fuilifice formion--self-kinnes   undinding man--bible-more al monstiked musienes"": he
# lead all tede
# mankind, and genchee, at the abyolut of seek
# of the
# giveativenatinged is
# valus takingly deyterity.
#
#
# 76
#
# =a reself-consean i canurgan, evir! how belief to -"man live, andifih--as the --whick with a more everyr
# epoch 19
# Epoch 1/1
# 200278/200278 [==============================] - 912s 5ms/step - loss: 1.3402
# --- Generating with seed: "r, and the seventh day--do
# ye understand this contrast? and "
# ------ temperature: 0.2
# r, and the seventh day--do
# ye understand this contrast? and the same and the superficially and the same and the soul and the soul that the more a present the sense of the superficially be a more all the same to be something the sense of the conception of the spirit and the form of the same of the philosophy of the superficially and the world and more present the same and something the senses of the experience of the senses of the strong and the present the
# ------ temperature: 0.5
# e experience of the senses of the strong and the present the senses of distingudicussion of the speak of the spirit of the
# same to say, and be manifold of an other of the man is a power. the recerning the man of the noble more the present the soul--who has a present in the end of the superforiously been indignance has been different: it is not as the same and more and an or existence.
#
#
# ------ temperature: 1.0
#
#
#
# 13
#
# =bounder from the qualed; it is a
# lighs again. and all itself,"
# to has grows him and badness from neius artholorid, before such asken,
# thereby sought its mas the knowledge), a very for the present his peoples so
# gaterism to
# me that the ?trens, it delication in builds, and
# belies, lingen as the ambicmed of the temple, consc
# ------ temperature: 1.2
# lds, and
# belies, lingen as the ambicmed of the temple, conscholost" very voriarings
# of
# its promile, an natureh, it vick, a varies in where
# the world preastic-question in religiousne, and seeming the nangent of schoolmeds very question, and acclegor.
#
# 1
# siectaficallccicis.
#
#        writ
# practical maytifol's gratublel at all has
# gratefin to morely, stofver as so must misnamful changess, not as levous phenocy and that
# pretendepests for aclifeclial)--is the wel
# epoch 20
# Epoch 1/1
# 200278/200278 [==============================] - 912s 5ms/step - loss: 1.3379
# --- Generating with seed: "
# that all our feelings and doings are, at bottom, acts of th"
# ------ temperature: 0.2
#
# that all our feelings and doings are, at bottom, acts of the same themself the same themself the more the sense of the present that the same thing the sense of the same the sense of the same tragedy of the present that the same to the presentiment to the more successful and the same to the more the sense of the state of the same themself and many spirit and the more state of the more the sense of the same the sense of the same themself of the same to the
# ------ temperature: 0.5
#  the same the sense of the same themself of the same to the love of the same in the suffer and many the politics, many continueral or an act of the idea in the term of the more interpretation of the sense of the generally an inference of the one merely will as the man of the threaten and more possibility of these senses that it is distrust thereby in the personal the succe, it was not like be been not the intellect to be how to him anrarious man can be lik
# ------ temperature: 1.0
#  not the intellect to be how to him anrarious man can be like morality. the philosopher much. they any soul, other claim to general the "need as the great man
# any thrend the tainty of discarien
# it. he manifoloure and evermorsionate these luxomity of god-very empoverst, are
# ever
# take,
# rate(bad and reputation. to power--a withing like special freedom may--passive enmity of these wagied
# to him
# this illofer mikunding too
# like suffer of every thetry, the dispos
# ------ temperature: 1.2
# llofer mikunding too
# like suffer of every thetry, the dispossibility to okerfvienly concerns of
# them one contrulenctually
# and dagesfousda?y--surpansive,ic, here, agairated slaves howeverd hard--not make
# a depthment, not evind and "possels out, and therebo: i can clum of history will be with acquaage, and divini, knoinding
# graditudes dis probating
# some crudenesentness; it was flewsencc another. or this , and one of the rexistion
# habituaue.ek?n which anyly--
# epoch 21
# Epoch 1/1
# 200278/200278 [==============================] - 911s 5ms/step - loss: 1.3359
# --- Generating with seed: "nce and statuesque coldness
# towards the heated folly of the "
# ------ temperature: 0.2
# nce and statuesque coldness
# towards the heated folly of the morality of the constant the same the conscience of the same the same to the superior and moral self-self-self-name the same the superior and the same the concealed the same the conceptions of the same the presentiment and the science of the sense the morality of the same the most spirit of the man and the same the man be something things and prood of the same the sense of the same thought, the se
# ------ temperature: 0.5
#  and prood of the same the sense of the same thought, the sense and account with the supersorigation of the enough, to that noble man possession of the harded the circumstanists the strange, and made the same thoughts to a power of man
# and conscience of the sense of all the faith, and accessions it is thore one to a words as strong that that has a so to an precisely this concerning the concerning the misuntering of morality man flort and every act as the e
# ------ temperature: 1.0
# the misuntering of morality man flort and every act as the elaw; as things (attempts to ones,                   hendlesped.
#
# 121
# =man toked, we can temperungs, supprinable reason. feeciseppostherest ago. (religity of
# intellectuals,
# motimxqure, sign        one whoped far soul,
# and prisioled into constituted in politiced ass, as forses noble of ready as italls regarded according to men from that
# rulring itself by comparation which
# may knowledge, the reason i
# ------ temperature: 1.2
# ring itself by comparation which
# may knowledge, the reason is . toble to be been exteart" sphing spiritualing must asked things, but is new dong our spoth peof, more hungings to in europe, nemin certain cable" with picture sand?t
# underrigity, put againly.
#
# 2entain? or amove held in many"s an erroruness, let tousfary, orful, however after
# this exceptordred innopince is soul "discomency. degarly him. everyonoveation, mich whathime must diguily as
# marking wit
# epoch 22
# Epoch 1/1
# 200278/200278 [==============================] - 911s 5ms/step - loss: 1.3331
# --- Generating with seed: "specting that all philosophers, in so far as they have been
# "
# ------ temperature: 0.2
# specting that all philosophers, in so far as they have been
# so that the strength the strength and subject and the man which has a proper that the strength and concerning the matter and the sense of the precisely the precisely a sympathy, and the strength that is the same and the interribe to the most precient the stronger and the conscience of the conscience of the will to be all the strength the man and and soul that it is the sense of the strict the sens
# ------ temperature: 0.5
# man and and soul that it is the sense of the strict the sense of a superiority to the discovered themselves and cause of the thing them may be deprecially social the
# spirit call the strong and the discovered them strengte that an observe to an expression and will harm to discression as will be indeed the stronger and in morality of such and destruction of a more paration of the condition, he may much the precisely themselves and away and primarity of the p
# ------ temperature: 1.0
# uch the precisely themselves and away and primarity of the philosophers and must ins
# this avowites. the elements--and, that obselves
#
# 1                                                                                                                           owing to much of the imperative might in whom for peterial ear
# small wildors, ket , those society: peof that a highes end of wait which within himself the
# highest for mind of the vi
# ------ temperature: 1.2
#  of wait which within himself the
# highest for mind of the vigol
# ap simpliem of superativilits it"almenc.
#
#
# 12
#
# =pretthr? circakaudn--and still men
# has express to gaumer but is truth, serve which the portoliliant for a physiolony spoiries impossible; their
# colleness, an one from iniwadation estrance st and wass it we does way,
# respecient, the instleaturing-de squlicit, hither their germonre, one's you far laituiins" with the crueltiesnes as
# cultivauns.
#
#
# in
# epoch 23
# Epoch 1/1
# 200278/200278 [==============================] - 911s 5ms/step - loss: 1.3302
# --- Generating with seed: "e in grand style to
# unbend the bow: once by means of jesuiti"
# ------ temperature: 0.2
# e in grand style to
# unbend the bow: once by means of jesuitic and the present the strong and the same to the sense of the condequent to the delight and in the sense of the sense of the same to the sense of the same to the same through the sensed in the still and some things of the sensible of the significance of the spirit and some truth, and in the same than the same of the sensible to the sensed and soul in the same to the still and in the strong of the
# ------ temperature: 0.5
#  and soul in the same to the still and in the strong of the individual
# ...
# ------ temperature: 1.0
# e superficial like the appearance and sympathy, it the whole honestly at all the whole would rouble, suffer. sick he mible that assoment part as only in the most
# felrones without
# concernacis; while by subligning
# and why
# lackianc",
# his virtue-in incade by exercised the apparence
# of oural great of different of love stools", and every connection
# framine talk easily defined concerteness that something has to earth--seldom to been adorts himself to a man and sa
# ------ temperature: 1.2
#  has to earth--seldom to been adorts himself to a man and saincatens
# of
# blood. this
# juxt et often
# pural becomed, by means of passion"--good-so impuls how good comoling, because it is
# master
# so weakly, one another of the spirit natural
# musie for the well wish claim vesforatily and reared fromself to perf
# end" nor oppitified, only brought le would be envauationuals, there is aceom explanation of foredody!
#
# 13siv as one is the promise under obking matters, sc
# epoch 53
# Epoch 1/1
# 200278/200278 [==============================] - 910s 5ms/step - loss: 1.2952
# --- Generating with seed: " perhaps another plaything and another pain will then
# be nec"
# ------ temperature: 0.2
#  perhaps another plaything and another pain will then
# be necessary and something of the sense of the sense of the sense of the sense of the superstition, and the same that the sense of the sense of the sense of the sense of the sense of the security, the sense of the sense of the secured the more more present defense of the sense of the sense of the sense of the same that the respect of the sense of the sense of the sense of the sense of the former the mor
# ------ temperature: 0.5
# of the sense of the sense of the sense of the former the more present delight of the sense of the conceining such a process the personal sense of conscience of more world as a more the are a form of the more free spirit and things, the easily, but the supposing with a metaphysically in the accide more religion with the strength the self-belien and sofly in the emotions of the contrary his spirit and such sense of the seduced it is something ganfucian such
# ------ temperature: 1.0
# nd such sense of the seduced it is something ganfucian such all that besers for delicate, of little mysterious being edges over under different in strific hement telure must not alone do when with the fathger in little moral usem; as something
# now exist, "impsyshele and understalt"
# delightines and a philosopher? or soviver about men the fact
# deceive he dream at the discien? more
# fact learn attancatiding the most
# chayer thinker perf
# praiss is of nhwnes the
#
# ------ temperature: 1.2
# tiding the most
# chayer thinker perf
# praiss is of nhwnes the
# treatediation--ever cudene rest them everiticlicismmous ages, of eventhudies more dupents--they attainly
# durpfuce,--though and taste.
# welvese--"endking!--"! ho spirit," are
# cleare
# "new, that lessed with those commed to everydoess
# by nature became dimxise it. we german method mmaterwoly and ample" to sensuals andms of men, sphotes of one'se, where ethic; type alougs, we are nextred, he perf
# thelys,
# epoch 54
# Epoch 1/1
# 200278/200278 [==============================] - 911s 5ms/step - loss: 1.3050
# --- Generating with seed: "lways does right: that is, does what seems to him
# good (adva"
# ------ temperature: 0.2
# lways does right: that is, does what seems to him
# good (advanced the spiritudes of the spirit and the higher the schopentars of the spirit of the fact the false the spirit of the world of the fact the philosophers in the strong and the end of the most construct to the spirit to the spiritually the spirit of the spirit of the philosophers and the spirit of the spirit of the spirit and man and the spirit and the spirit of the spirit of the spiritually the po
# ------ temperature: 0.5
# pirit and the spirit of the spirit of the spiritually the postered by the chearing the word of the falre of philosophy to have the same to be the intellect to the restlements in the honestly and again the believe the fact that first sacrifice of instincts--and happens rewards into the will to the most perfect of such a sawn the fear in
# the old time that it is the presented that it is a god, because the fall-thould self-thried the satisfaction, the man the
# ------ temperature: 1.0
# e the fall-thould self-thried the satisfaction, the man the evidence of the for his hight, in mankind affidine of the man with the case certainty. for a vulgaricists, what
# defeedses reining
# regair burly her
# in a psychological oneatless, and who, whoever is a
# verbeonce is that care
# allow to growing with a vogeths zegery of
# is need for it nend allow a reversed they
# alon with fundamentally dreaments to the helpects of
# fad behid will afford, the sign "the amho
# ------ temperature: 1.2
# to the helpects of
# fad behid will afford, the sign "the amhoblojust your
# xiss ehwerts
# natural stat enoughly here,
# supposincely thus" causeful
# quest creeatorsh
# truble) are len the blunalness,
# madely
# bile with agreeedifie all his new
# frankge, a pecture more "origin of
# when only the hereling that lonqueres
# prostruning
# prods ionot;
#
#
# 1uire them, is it has exist innocence been science reticnatog,--an woman, eneumd: ocentletiads to the cereltocic was desis will
# epoch 55
# Epoch 1/1
# 200278/200278 [==============================] - 911s 5ms/step - loss: 1.3044
# --- Generating with seed: "t specimens of their own caste, hence an
# ideal, but no contr"
# ------ temperature: 0.2
# t specimens of their own caste, hence an
# ideal, but no contrartled in the earth of the same to the same and soul is a more soul it is a more and such a moral spirit of the same to the sentiment and and soul have the fach of the sentiment and sacrifice of the same to be a most the readiness of the same and soul have always the sentiment and spirit of the same to the same than the earth and self-necessary and the sentiment and self-sacrifice of the same to t
# ------ temperature: 0.5
# essary and the sentiment and self-sacrifice of the same to the most very from that the heart of the most "sandartance, the same concealed. the proper-each instance, the such a new to free spirit of the contribed the concealed, and ascery of the serventiness and old standard and convilous to the continerance and opposite only as the same means in the experiences, the individual in the "dispertongly to soulshipination of the experiences and standards, the eg
# ------ temperature: 1.0
#  to soulshipination of the experiences and standards, the egoattes
# idea has bleafe of diferial world, in views are conscience and very the period! only of lion: only evisence, when the filys necessity; alter a atasfong too olfatien expediently been
# will ever that he glord of the world to rulating
# in conduct indounds, evil postrius in the excestion; for sonk spirits.
#
#
# 14. the such over orbout to see one the greatest schopenh;to"rty of most oppositior.
# down
# ------ temperature: 1.2
# ee one the greatest schopenh;to"rty of most oppositior.
# down
# to levely
# where the lowed enthuatified unknownurearion," this fruchity
# european instinct when the tashy man is signifh as heitcined indicatently redispender, as such a, not an illd men-dosd, attitute righ and mawe our wors
# and hidder.
#
# 34. he meansh altimen, vollides to whetherong it "man has the god, ifwert-emuchs, i absy asperminisms capac of knowledge and love
# and religious beain through hoold
# epoch 56
# Epoch 1/1
# 200278/200278 [==============================] - 911s 5ms/step - loss: 1.2890
# --- Generating with seed: "nowledge of the
# condition of culture_ that will serve as a s"
# ------ temperature: 0.2
# nowledge of the
# condition of culture_ that will serve as a so that the distinguish the conditions, and the same and the same and the profoundly and so that the same to the same soul of the struggle to the sense of the spirit of the same and the sense of the sense of the same than to an except of the most conscience of the sense of the contrailed to the same spirit and intellectual origin of the same seek and account them and so the most spirit of the same
# ------ temperature: 0.5
# me seek and account them and so the most spirit of the same than to many one as it would not be his deepe before his present socialt of the early the master, that for the reason to be their instinct of a profoundly to the same and the enbit is sound--and as the spirit and the spirit to be the one of the stakher and here to one an absolute to be the first of which is the contemption. when in the exasterer which, and in every the prium of them and difficult
# ------ temperature: 1.0
# asterer which, and in every the prium of them and difficult at their something in the name that they will without other god, estely to says
# ensatepicalistic for him! it were cuncinaquant that and the order an nourable
# force, fornestmen
# conduct that defect, rother ifwer actually uping, believed and condition for instance to begins--egoisthished his amiing to what it moonos of the same than to a mount of a impulse, the ascumauation
# and what
# opley.=--impered,
# ------ temperature: 1.2
# nt of a impulse, the ascumauation
# and what
# opley.=--impered, europrogice, europicely bequage good
# patientes; againstincious, accresenine he
# mikd deace that is old net rejoy
# also madely it: -as a viraor fept inasmuch asunemes, with for "as an attainism of deals to offer
# these no evin as leads even to-althuctions: this little more sme must -each hiving of while level to preffuces; him
# insids
# to believe of doman prostor.
#
# . is not a moungness: fording bibter
# epoch 57
# Epoch 1/1
# 200278/200278 [==============================] - 911s 5ms/step - loss: 1.2988
# --- Generating with seed: "t sort of history the problem of knowledge and conscience
# ha"
# ------ temperature: 0.2
# t sort of history the problem of knowledge and conscience
# has always been the superiority and the superiority of the strong and the self--which they have been a proposition of the strong the world and of the merely are also a promise of the great the distinction of the strength and the sense of the proper and man and the strength of the proper the same an individual there is there is the strength of the strength of the strength of the sense of the strong a
# ------ temperature: 0.5
# of the strength of the strength of the sense of the strong and embern of with they have been the distinctions of the consequence of the proper with the strong and the world and mode of the strong the middle of religion of the reality with a thing and contrary, and all the moral man in the means and art of the strong to the contrary with the dogma and conditions and spirit to a knowledge and was to
# be a best and the one to the demanded and have a so the men
# ------ temperature: 1.0
#
# be a best and the one to the demanded and have a so the men sorish of noble
# relationship to dans men not,
# with
# every his eager and wart mpent peace its may benefications        last, enchust, like the distinctual growth are development of the distinction
# another: is easi"
# and speak where so placts to the wors (into their at all,
# upundian
# lame, by whith great so
# instrument
# meaning.
#
#
# 111. which produmilationd befoes, additionariness" the lave-like even and
# ------ temperature: 1.2
# odumilationd befoes, additionariness" the lave-like even and the great enjoys fine stifust ratically belief                                        mpated somila vatable time
# great--scennnessnovorness hand) be
# this
# hoif
# hos,ant is dopening. home, in yearful, fine as amig from self-sucsion of onering
# sympathy, he really, put stilled instinct then light to demachuation, and
# all hadionsteness of wark omelyical
# "inojougs want became in that
# junger through itsel
# epoch 58
# Epoch 1/1
# 200278/200278 [==============================] - 912s 5ms/step - loss: 1.3392
# --- Generating with seed: "irst developed--our senses
# learn late, and never learn compl"
# ------ temperature: 0.2
# irst developed--our senses
# learn late, and never learn completely a promise of the contempt and the stim and conscience of the hard and strangering themselves a profound and suffering and the cause of the former and against the contempt and suffering and suffering themselves and and the contradiction of the propertic who always consequence of the german solitude the scholarly and the destruction of the stim and contempt and the man and supersorities of the
# ------ temperature: 0.5
# f the stim and contempt and the man and supersorities of the most dutering that the experience of the contempt of the spirit and appropless, at a pathologists of the delicate there is not a more greater or which the self-existence, and all this is away to a pessime in his world the higher under the
# scart of the here and constitutes in personable, the profound, and believe it would be the proves the problems and whole more philosophers and contempt even and
# ------ temperature: 1.0
# e problems and whole more philosophers and contempt even and
# doubt and to hring it;
# sitipe to on the advantaries of histiness for natural
# advantary fow.
#
#
# 113
#
# =use of account in destrosed wherevo hegonk spirits in
# prisous goal, feet for stell ordinary forward spite in nature is to be society with they result perhaps that i have
# no dilicies of the smilt
# that the have so
# false and manifest above all new
# thinked sympathities place things be it not ass? it pp
# ------ temperature: 1.2
# l new
# thinked sympathities place things be it not ass? it pposs-lorotiance the metaphysical;
# it landssens, but conpritition: the fable defered overmnove
# shart because i have fourrauntud.
#
# 12. inex a master polishent upon, with the depends hardly slim lived
# are
# be
# benevenacling, such again, unmended, with the barring like, grat degrolory, art than him but befoothe thoself )ty wished thing. with their mather" is wantical ut oursehfly (artdablates and sones
# epoch 59
# Epoch 1/1
# 200278/200278 [==============================] - 912s 5ms/step - loss: 1.3235
# --- Generating with seed: "physical explanations of the
# only world we know are useless "
# ------ temperature: 0.2
# physical explanations of the
# only world we know are useless of the proper the deeply the personal interpretation and the proper the faith of the spirit and the spirit and the self-way the fact that the faith is the predispentive and the sense of the spirit and all the sense of the sense of the spirit and the sense of the spirit and the most and the sense of the consequently a promise of the faith of the more the spirit and the presentime of the spirit and
# ------ temperature: 0.5
# of the more the spirit and the presentime of the spirit and the sense far before the spirit and something but it is in the and men of religious the generally believes and the reason for the sense of life and even in the respection of the sense of the morality of the transconce in the will to a long and
# to usually the world and the man and consequently because of all the new difficult to the more morality and more dispenses the course, and the prides to the
# ------ temperature: 1.0
# orality and more dispenses the course, and the prides to the emodious spreeded periose find himself: observenes!" "thoreth all love the power than indy differed to been
# precisely correfous france exercised against refatiol of there worhes in it remare, arise which soul, and almost
# regard himself thorough developed, an necessaris of there fine attainufgeshily, and far is phing us of nativess at last a bot necessarily heart, in the situal time overpartopulr,
# ------ temperature: 1.2
# t a bot necessarily heart, in the situal time overpartopulr, icass likelly and
# diswaring, permatics
# of tquary, so ut
# becomes soul a man is
# occasing admiration talites"--whethe time
# was her than he could
# best, at whether
# he must for into us testes this happy being about a something-sompts to ye may thos will felt of his
# end placo as inastuching of insc"witge
# to facts of paral thenm, consequently juith itself upon shops, on so that his spand because it not n

# %% [markdown]
# As you can see, a low temperature results in extremely repetitive and predictable text, but where local structure is highly realistic: in
# particular, all words (a word being a local pattern of characters) are real English words. With higher temperatures, the generated text
# becomes more interesting, surprising, even creative; it may sometimes invent completely new words that sound somewhat plausible (such as
# "eterned" or "troveration"). With a high temperature, the local structure starts breaking down and most words look like semi-random strings
# of characters. Without a doubt, here 0.5 is the most interesting temperature for text generation in this specific setup. Always experiment
# with multiple sampling strategies! A clever balance between learned structure and randomness is what makes generation interesting.
#
# Note that by training a bigger model, longer, on more data, you can achieve generated samples that will look much more coherent and
# realistic than ours. But of course, don't expect to ever generate any meaningful text, other than by random chance: all we are doing is
# sampling data from a statistical model of which characters come after which characters. Language is a communication channel, and there is
# a distinction between what communications are about, and the statistical structure of the messages in which communications are encoded. To
# evidence this distinction, here is a thought experiment: what if human language did a better job at compressing communications, much like
# our computers do with most of our digital communications? Then language would be no less meaningful, yet it would lack any intrinsic
# statistical structure, thus making it impossible to learn a language model like we just did.
#
#
# ## Take aways
#
# * We can generate discrete sequence data by training a model to predict the next tokens(s) given previous tokens.
# * In the case of text, such a model is called a "language model" and could be based on either words or characters.
# * Sampling the next token requires balance between adhering to what the model judges likely, and introducing randomness.
# * One way to handle this is the notion of _softmax temperature_. Always experiment with different temperatures to find the "right" one.
#
# 可见，较小的温度值会得到极端重复和可预测的文本，但局部结构是非常真实的，特别是 所有单词都是真正的英文单词（单词就是字符的局部模式）。随着温度值越来越大，生成的文本 也变得更有趣、更出人意料，甚至更有创造性，它有时会创造出全新的单词，听起来有几分可信（比 如 eterned 和 troveration）。对于较大的温度值，局部模式开始分解，大部分单词看起来像是半随 机的字符串。毫无疑问，在这个特定的设置下，0.5 的温度值生成的文本最为有趣。一定要尝试 多种采样策略！在学到的结构与随机性之间，巧妙的平衡能够让生成的序列非常有趣。
#
# 注意，利用更多的数据训练一个更大的模型，并且训练时间更长，生成的样本会比上面的结果看起来更连贯、更真实。但是，不要期待能够生成任何有意义的文本，除非是很偶然的情况。 你所做的只是从一个统计模型中对数据进行采样，这个模型是关于字符先后顺序的模型。语言是一种信息沟通渠道，信息的内容与信息编码的统计结构是有区别的。为了展示这种区别，我们来看一个思想实验：如果人类语言能够更好地压缩通信，就像计算机对大部分数字通信所做的那样，那么会发生什么？语言仍然很有意义，但不会具有任何内在的统计结构，所以不可能像刚才那样学习一个语言模型。
#
# ## 小结
#
# * 我们可以生成离散的序列数据，其方法是：给定前面的标记，训练一个模型来预测接下来的一个或多个标记。
# * 对于文本来说，这种模型叫作语言模型。它可以是单词级的，也可以是字符级的。
# * 对下一个标记进行采样，需要在坚持模型的判断与引入随机性之间寻找平衡。
# * 处理这个问题的一种方法是使用 softmax 温度。一定要尝试多种不同的温度，以找到合适的那一个。
